# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
MODEL = "CGB" # "RFC", "LRC"

# %%
intervals = pd.DataFrame([[-259.1, -254.14], 
                          [-254.14, -251.902], 
                          [-251.902, -251], 
                          [-251, -250.4]], 
                         index=["Wuchiapingian",
                                "Changhsingian",
                                "Extinction",
                                "Griesbachian"], 
                         columns=["from", "to"])

intervals["mid"] = intervals.mean(axis=1)

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12), sharex=True, sharey=True)
axes = axes.ravel()

# loop over all analyzer Time Intervals
for i in range(1, 5):
    
    # read obtained feature importances
    fi = pd.read_csv(f"../results/{MODEL}_TimeInterval{i}_FI.csv", index_col=0).T
    
    # calculate mean over the 5 splits
    fi["mean"] = fi.mean(axis=1)
    
    # create a figure
    sns.heatmap(fi, cmap="Reds", ax=axes[i-1], square=False, annot=True, cbar_kws={'label': 'relative importance, %'})
    
    axes[i-1].set_title(intervals.index[i-1])

fig.savefig("../results/figures/FI_individual.png", bbox_inches="tight", dpi=300)

# %%
# placeholder for collecting individual AUCs
aucs = []

# loop over all analyzer Time Intervals
for i in range(1, 5):
    
    # read obtained AUCs
    auc = pd.read_csv(f"../results/{MODEL}_TimeInterval{i}_AUC.csv", index_col=0).T
    
    # calculate mean over the 5 splits
    #auc["mean"] = auc.mean(axis=1)
    
    # change index of the collected dataframe accordingly
    auc.index = [intervals.index[i-1]]
    
    # append to the placeholder for further concatenation
    aucs.append(auc)

aucs = pd.concat(aucs, axis=0)
aucs = aucs.T

# %%
aucs
# Out:
#         Wuchiapingian  Changhsingian  Extinction  Griesbachian
# Split1       0.808889       0.799699    0.858117      0.724401
# Split2       0.620833       0.706043    0.742484      0.778867
# Split3       0.637387       0.851031    0.709477      0.640271
# Split4       0.577327       0.790134    0.796405      0.625566
# Split5       0.751502       0.842391    0.826144      0.796380

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(aucs.columns.tolist(), aucs.mean().values, c="k", linestyle="-", marker="o", label="mean AUC")
sns.swarmplot(data=aucs, ax=ax)

ax.set_ylabel("AUC")
_ = ax.legend()

fig.savefig("../results/figures/AUC_individual.png", bbox_inches="tight", dpi=300)
